# %% [markdown]
# Name : Namrata Subhash Narkhede
#
# Moodle id : 20102106
#
# Roll No :115
#
# Sub : ML LAB
#
# # Experiment No : 03

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
 from sklearn.linear_model import LinearRegression
 from sklearn.model_selection import train_test_split

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_csv('/content/HRPDataset.csv')
print('Defining X and Y variables...')
x = df['Area']
y = df['Price']
# Out:
# Defining X and Y variables...

# %%
plt.scatter(x,y, color = 'blue')

# %%
print("Splitting the dataset into Training data and testing data")
x_train, x_test, y_train, y_test =  train_test_split(x, y  , random_state = 0)
# Out:
# Splitting the dataset into Training data and testing data

# %%
plt.scatter(x_train,y_train, color = 'green')

# %%
plt.scatter(x_test,y_test, color = 'red')

# %%
print('Training the model using x-train and y-train')
lr = LinearRegression()
lr.fit(x_train.values.reshape(-1,1),y_train)
# Out:
# Training the model using x-train and y-train
# LinearRegression()

# %%
print('Predicting using the trained model for the values of x_test')
y_pred = lr.predict(x_test.values.reshape(-1,1))
# Out:
# Predicting using the trained model for the values of x_test

# %%
print(y_test)
print(y_pred)
# Out:
# 28    6550000
# 11    4212500
# 10    4075000
# 41    8337500
# 2     2975000
# 27    6412500
# 38    7925000
# 31    6962500
# 22    5725000
# 4     3250000
# 33    7237500
# 35    7512500
# 26    6275000
# Name: Price, dtype: int64
# [6550000. 4212500. 4075000. 8337500. 2975000. 6412500. 7925000. 6962500.
#  5725000. 3250000. 7237500. 7512500. 6275000.]

# %% [markdown]
# ### **Linear Regression on Placement data**

# %%
df= pd.read_csv('/content/Placement (1).csv')

# %%
df.head()
# Out:
#    ï»¿cgpa  package
# 0     6.89     3.26
# 1     5.12     1.98
# 2     7.82     3.25
# 3     7.42     3.67
# 4     6.94     3.57

# %%
df.tail()
# Out:
#      ï»¿cgpa  package
# 195     6.93     2.46
# 196     5.89     2.57
# 197     7.21     3.24
# 198     7.63     3.96
# 199     6.22     2.33

# %%
df.describe()
# Out:
#           ï»¿cgpa     package
# count  200.000000  200.000000
# mean     6.990500    2.996050
# std      1.069409    0.691644
# min      4.260000    1.370000
# 25%      6.190000    2.487500
# 50%      6.965000    2.995000
# 75%      7.737500    3.492500
# max      9.580000    4.620000

# %%
plt.scatter(df['ï»¿cgpa'], df['package'])
plt.xlabel('CGPA')
plt.ylabel('Package(in lpa)')
# Out:
# Text(0, 0.5, 'Package(in lpa)')

# %%
x = df.iloc[:, 0:1]
y = df.iloc[:, -1]

# %%
y
# Out:
# 0      3.26
# 1      1.98
# 2      3.25
# 3      3.67
# 4      3.57
#        ...
# 195    2.46
# 196    2.57
# 197    3.24
# 198    3.96
# 199    2.33
# Name: package, Length: 200, dtype: float64

# %%
x_train, x_test, y_train, y_test =  train_test_split(x, y  ,test_size = 0.2, random_state = 2)

# %%
plt.scatter(x_train,y_train, color = 'green')

# %%
plt.scatter(x_test,y_test, color = 'red')

# %%
lr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
lr.predict(x_test.iloc[0].values.reshape(1,1))
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([3.89111601])

# %%
plt.scatter(df['ï»¿cgpa'], df['package'])
plt.plot(x_train, lr.predict(x_train), color = 'red')
plt.xlabel('CGPA')
plt.ylabel('Package(in lpa)')
# Out:
# Text(0, 0.5, 'Package(in lpa)')

# %%
m = lr.coef_
m
# Out:
# array([0.55795197])

# %%
b = lr.intercept_
b
# Out:
# -0.8961119222429144

# %%
m*8.58+b
# Out:
# array([3.89111601])
